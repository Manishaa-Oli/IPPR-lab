# %% [markdown]
# <a href="https://colab.research.google.com/github/Manishaa-Oli/IPPR-lab/blob/main/lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Write a program to find Erosion of an image.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('/content/pkr.png', 0)
kernel = np.ones((3,3), np.uint8)
erosion = cv2.erode(img, kernel, iterations=1)

plt.figure(figsize=(12, 6))  #increases display size

plt.subplot(121)
plt.imshow(img, cmap="gray")
plt.title('Original')
plt.xticks([]), plt.yticks([])

plt.subplot(122)
plt.imshow(erosion, cmap="gray")
plt.title('Erosion')
plt.xticks([]), plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('/content/pkr.png', 0)
kernel = np.ones((3,3), np.uint8)
dilation = cv2.dilate(img, kernel, iterations=1)

plt.figure(figsize=(12, 6))

plt.subplot(121), plt.imshow(img, cmap="gray"), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(dilation, cmap="gray"), plt.title('dilation')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Write a program to find opening of an image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('/content/pkr.png', 0)
kernel = np.ones((3, 3), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(opening), plt.title('Opening')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Write a program to find closing of an image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('pkr.png', 0)
kernel = np.ones((3, 3), np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(closing), plt.title('Closing')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### Write a program to find Morphological gradient of an image

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('pkr.png', 0)
kernel = np.ones((3, 3), np.uint8)
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernel)
plt.subplot(121), plt.imshow(img), plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(gradient), plt.title('Gradient')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ###
